# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.4.48  Python-3.11.9 torch-2.11.0+cpu CPU (Intel Core Ultra 7 255H)
# Setup complete  (16 CPUs, 31.4 GB RAM, 291.0/952.9 GB disk)

# %%
from ultralytics import YOLO

# COCO 사전 학습된 YOLOv3u 모델 로드
model = YOLO("yolov3u.pt")

# 모델 정보 표시 (선택 사항)
model.info()

# COCO8 예제 데이터셋으로 100 에포크 동안 모델 학습
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
# Out:
# ...
# YOLOv3 summary: 180 layers, 103,754,144 parameters, 0 gradients, 283.3 GFLOPs
# Ultralytics 8.4.48  Python-3.11.9 torch-2.11.0+cpu CPU (Intel Core Ultra 7 255H)
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train-4/weights/best.pt')  # 학습된 모델 로드
model.save("yolov3u.pt")  # 모델 저장

# %%
model_load = YOLO("yolov3u.pt")  # 저장된 모델 로드

# %%
result = model_load.predict("bus.jpg")
# Out:
# image 1/1 c:\Data\computer_vision\YOLO3\bus.jpg: 640x480 4 persons, 1 bus, 549.3ms
# Speed: 2.4ms preprocess, 549.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)

# %%
result
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
result[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
result[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5., 0., 0., 0., 0.])
# conf: tensor([0.9587, 0.9190, 0.9010, 0.8855, 0.6066])
# data: tensor([[2.1234e+00, 2.2972e+02, 8.0587e+02, 7.4100e+02, 9.5870e-01, 5.0000e+00],
#         [6.6761e+02, 3.8493e+02, 8.0962e+02, 8.8031e+02, 9.1901e-01, 0.0000e+00],
#         [4.9726e+01, 3.9658e+02, 2.4957e+02, 9.0506e+02, 9.0104e-01, 0.0000e+00],
#         [2.2432e+02, 4.0568e+02, 3.4473e+02, 8.6098e+02, 8.8553e-01, 0.0000e+00],
#         [1.7157e-01, 5.4955e+02, 7.9163e+01, 1.0683e+03, 6.0663e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (1080, 810)
# shape: torch.Size([5, 6])
# xywh: tensor([[403.9968, 485.3588, 803.7468, 511.2850],
#         [738.6129, 632.6191, 142.0046, 495.3793],
#         [149.6500, 650.8177, 199.8487, 508.4783],
#         [284.5255, 633.3315, 120.4050, 455.2958],
#         [ 39.6672, 808.9292,  78.9913, 518.7640]])
# xywhn: tensor([[0.4988, 0.4494, 0.9923, 0.4734],
# ...

# %%
result[0].boxes.cls
# Out:
# tensor([5., 0., 0., 0., 0.])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for re in result:
    name = [re.names[cls.item()] for cls in re.boxes.cls.int()]
    confs = re.boxes.conf

# %%
name
# Out:
# ['bus', 'person', 'person', 'person', 'person']

# %%
confs
# Out:
# tensor([0.9587, 0.9190, 0.9010, 0.8855, 0.6066])

# %%
result[0].names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...
