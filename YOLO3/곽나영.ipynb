# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# CIFAR-10 클래스 이름
CLASS_NAMES = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"
]

# %%
def classify_image(model, image):
    results = model(image)
    probs = results[0].probs
    top1_index = probs.top1
    top1_conf = probs.top1conf.item()
    # predicted_class = CLASS_NAMES[top1_index]
    predicted_class = results[0].names[top1_index]
    print(f"예측 클래스: {predicted_class}")
    print(f"신뢰도: {top1_conf:.4f}")
    
    image = cv2.imread(image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(6, 6))
    plt.imshow(image)
    plt.title(f"Predicted: {predicted_class} ({top1_conf:.2f})")
    plt.axis('off')
    plt.show()

# %%
model = YOLO("yolo26n-cls.pt")
image = "cat.jpg"

# CIFAR-10 학습
# model.train(
#     data="cifar10",
#     epochs=50,
#     imgsz=32,
#     batch=128
# )

classify_image(model, image)
# Out:
# image 1/1 c:\Data\computer_vision\YOLO3\cat.jpg: 224x224 Egyptian_cat 0.89, tabby 0.04, radiator 0.01, Siamese_cat 0.01, window_shade 0.01, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 예측 클래스: Egyptian_cat
# 신뢰도: 0.8887

# %% [markdown]
# ---------------------

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
def classify_image(model, image):
    results = model(image)
    probs = results[0].probs
    top1_index = probs.top1
    top1_conf = probs.top1conf.item()
    # predicted_class = CLASS_NAMES[top1_index]
    predicted_class = results[0].names[top1_index]
    print(f"예측 클래스: {predicted_class}")
    print(f"신뢰도: {top1_conf:.4f}")
    
    image = cv2.imread(image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(6, 6))
    plt.imshow(image)
    plt.title(f"Predicted: {predicted_class} ({top1_conf:.2f})")
    plt.axis('off')
    plt.show()

# %%
model = YOLO("yolo26n-cls.pt")
image = "human.png"

classify_image(model, image)
# Out:
# image 1/1 c:\Data\computer_vision\YOLO3\human.png: 224x224 ballplayer 1.00, baseball 0.00, television 0.00, tennis_ball 0.00, basketball 0.00, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 예측 클래스: ballplayer
# 신뢰도: 0.9975
