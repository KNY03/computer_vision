# %%
from ultralytics import YOLO

model = YOLO('yolo26n.pt')

# COCO8 예제 데이터셋으로 100 에포크 동안 모델 학습
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
# Out:
# ...
# Ultralytics 8.4.48  Python-3.11.9 torch-2.11.0+cpu CPU (Intel Core Ultra 7 255H)
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train-5/weights/best.pt')
metrics = model.val()
# Out:
# Ultralytics 8.4.48  Python-3.11.9 torch-2.11.0+cpu CPU (Intel Core Ultra 7 255H)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 838.8411.5 MB/s, size: 54.0 KB)
# val: Scanning C:\Data\computer_vision\YOLO3\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          4         17      0.906      0.646      0.887        0.7
#                 person          3         10          1      0.378      0.802      0.417
#                    dog          1          1      0.794          1      0.995      0.895
#                  horse          1          2       0.86          1      0.995      0.795
#               elephant          1          2       0.78        0.5      0.543      0.302
# ...

# %%
metrics.box.map
# Out:
# np.float64(0.6999857422632481)

# %%
metrics.box.map50
# Out:
# np.float64(0.8874326319675157)

# %%
metrics.box.map75
# Out:
# np.float64(0.821875)

# %%
metrics.box.maps
# Out:
# array([    0.41665,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,      0.8955,       0.795,     0.69999,     0.69999,     0.30176,     0.69999,     0.69999,     0.69999,
#            0.69999,      0.8955,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,
#            0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,      0.8955,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,     0.69999,
# ...

# %%
metrics.box.image_metrics
# Out:
# {'000000000042.jpg': {'precision': 0.00625,
#   'recall': 1.0,
#   'f1': 0.012422360248447204,
#   'tp': 1,
#   'fp': 159,
#   'fn': 0},
#  '000000000061.jpg': {'precision': 0.029411764705882353,
#   'recall': 1.0,
#   'f1': 0.05714285714285715,
#   'tp': 5,
#   'fp': 165,
#   'fn': 0},
#  '000000000049.jpg': {'precision': 0.042328042328042326,
#   'recall': 0.8888888888888888,
#   'f1': 0.0808080808080808,
#   'tp': 8,
#   'fp': 181,
#   'fn': 1},
#  '000000000036.jpg': {'precision': 0.08333333333333333,
#   'recall': 1.0,
#   'f1': 0.15384615384615385,
#   'tp': 2,
#   'fp': 22,
#   'fn': 0}}

# %%
model.save('yolo26n-detect.pt')

# %%
detect_model = YOLO('yolo26n-detect.pt')

# %%
results = detect_model.predict('bus.jpg')
# Out:
# image 1/1 c:\Data\computer_vision\YOLO3\bus.jpg: 640x480 4 persons, 1 bus, 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)

# %%
for result in results:
    names = [result.names[cls.item()] for cls in result.boxes.cls]
    confs = result.boxes.conf

# %%
names
# Out:
# ['person', 'person', 'bus', 'person', 'person']

# %%
confs
# Out:
# tensor([0.9420, 0.9231, 0.9168, 0.9090, 0.7903])

# %%
results = detect_model.predict("bird.jpg")
# Out:
# image 1/1 c:\Data\computer_vision\YOLO3\bird.jpg: 480x640 1 bird, 84.5ms
# Speed: 2.2ms preprocess, 84.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)

# %%
for result in results:
    names = [result.names[cls.item()] for cls in result.boxes.cls]
    confs = result.boxes.conf

# %%
confs
# Out:
# tensor([0.9327])

# %%
names
# Out:
# ['bird']
